# %%
import gdown 

from IPython.display import clear_output 
import os

# %%
driveURL = "https://drive.google.com/file/d/1S9CwGNZENrRlu9HZfq214F3LjJKeoMdZ/view?usp=sharing"

downloadURL = 'https://drive.google.com/uc?export=download&id='+driveURL.split('/')[-2]
gdown.download(downloadURL)
DF = pd.read_csv('TNC_Combined_5000.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1S9CwGNZENrRlu9HZfq214F3LjJKeoMdZ
# To: /content/TNC_Combined_5000.csv
# 100%|██████████| 210M/210M [00:02<00:00, 104MB/s]

# %%
DF = DF[:-1]
DF
# Out:
#       Serials          Category  \
# 0       NACHM       Imaginative
# 1       NACHM       Imaginative
# 2       NACHM       Imaginative
# 3       NACHM       Imaginative
# 4       NACHM       Imaginative
# ...       ...               ...
# 40002  RLG005  Belief & Thought
# 40003  RLG005  Belief & Thought
# 40004  RLG005  Belief & Thought
# 40005  RLG005  Belief & Thought
# 40006  RLG005  Belief & Thought
#
#                                                    Texts
# 0        และนี่ก็เป็นเรื่องราวประวัติศาสตร์มาจนถึงสมั...
# 1        เช้านี้เดินเที่ยวในสถานีรถไฟใต้ดิน นึกครึ้มว...
# 2        อันว่าการมาเมืองจีนโดยมีเจ้าภาพเชิญนั้น ไม่ต...
# 3        นี้หรือที่นําหยก งาช้าง เพชรนิลจินดา ของมีค่...
# 4        แต่เอทําไมนะเขาถึงได้สนใจเขียนตัวเลขเต็มไปหม...
# ...                                                  ...
# 40002    ศาสนาเช่นพุทธศาสนา แม้จะไม่มีบทบัญญัติเช่นนั...
# 40003    ความเป็นอยู่ที่หรูหราฟุ่มเฟือยชนิดที่ไม่น่าจ...
# 40004    การให้ทานแก่ขอทานหรือเด็กกําพร้า จะมีอานิสงส...
# 40005    มีเรื่องเล่าในคัมภีร์ขงจื๊อว่ามีคนถามขงจื๊อเ...
# 40006    เนื้อความตอนที่สองของแนวคิดของท่านอชิตะ เกสก...
#
# [40007 rows x 3 columns]

# %%
DOMAIN_DICT = {
      0 : 'Imaginative',
      1 : 'Natural & Pure Science',
      2 : 'Applied Science',
      3 : 'Social Science ',
      4 : 'History',
      5 : 'Commerce & Finance',
      6 : 'Arts',
      7 : 'Belief & Thought'
  }

# %%
def findProportion(countValues, trainPercent=0.7, valPercent=0.15, testPercent=0.15, reservePercent=0.1, size=None):
  output={}
  sortedSerial = countValues.index

  if size != None:
    overallSize = size 
  else: 
    overallSize = int(len(DF) / 8)

  reserveSize = int(overallSize * reservePercent)
  dataSize = overallSize -  reserveSize


  trainSize =  int(dataSize * trainPercent)
  valSize = int(dataSize * valPercent)
  testSize = int(dataSize * testPercent)

  limits = [trainSize,valSize,testSize]
  splitTags = ['Train','Validation','Test']
  
  start_index = 0

  for splitIndex in range(3):
    count = 0
    limit = limits[splitIndex]
    propDict = {}

    for i, serial in enumerate(sortedSerial[start_index:]):
      Index = start_index + i 

      if count + countValues[Index] < limit:
        count+=countValues[Index]
        propDict[serial] = countValues[Index]

      elif count + countValues[Index] == limit:
        propDict[serial] = countValues[Index]
        start_index = Index + 1
        break

      else:
        propDict[serial] = limit - count
        start_index = Index + 1
        break

    output[splitTags[splitIndex]] = propDict
  return output

# %%
sampleDF = DF.loc[DF['Category'] == 'Imaginative']
countValue = sampleDF['Serials'].value_counts()

# %%
findProportion(countValue)
# Out:
# {'Test': {'NACHM': 15,
#   'PRNV011': 21,
#   'PRNV015': 22,
#   'PRNV018': 21,
#   'PRNV019': 20,
#   'PRNV033': 18,
#   'PRNV034': 23,
#   'PRNV046': 23,
#   'PRNV05': 20,
#   'PRNV060': 19,
#   'PRNV063': 18,
#   'PRNV065': 19,
#   'PRNV068': 20,
#   'PRNV069': 19,
#   'PRNV073': 23,
#   'PRNV082': 22,
#   'PRNV09': 19,
#   'PRNV091': 19,
#   'PRNV101': 22,
#   'PRNV108': 18,
#   'PRNV110': 23,
#   'PRNV111': 22,
#   'PRNV128': 21,
#   'PRNV129': 22,
#   'PRNV151': 19,
#   'PRNV160': 21,
#   'PRNV173': 17,
#   'PRSH010': 23,
#   'PRSH013': 23,
#   'PRSH015': 23,
#   'PRSH017': 20,
#   'PRSH019': 20,
#   'PRSH025': 20},
#  'Train': {'POET023': 50,
#   'PRNV': 51,
#   'PRNV001': 35,
#   'PRNV002': 42,
#   'PRNV003': 43,
#   'PRNV006': 61,
#   'PRNV007': 38,
#   'PRNV008': 67,
#   'PRNV01': 29,
#   'PRNV010': 44,
#   'PRNV012': 42,
#   'PRNV013': 53,
#   'PRNV014': 35,
#   'PRNV016': 47,
#   'PRNV017': 29,
#   'PRNV020': 31,
#   'PRNV022': 29,
#   'PRNV023': 41,
#   'PRNV024': 29,
#   'PRNV025': 58,
#   'PRNV026': 31,
#   'PRNV029': 29,
#   'PRNV036': 33,
#   'PRNV037': 29,
#   'PRNV039': 41,
#   'PRNV040': 32,
#   'PRNV044': 34,
#   'PRNV045': 31,
#   'PRNV047': 31,
#   'PRNV049': 29,
#   'PRNV052': 29,
#   'PRNV070': 32,
#   'PRNV071': 42,
#   'PRNV072': 29,
#   'PRNV081': 30,
#   'PRNV083': 6,
#   'PRNV085': 37,
#   'PRNV087': 31,
#   'PRNV088': 31,
#   'PRNV090': 33,
#   'PRNV092': 53,
#   'PRNV093': 75,
#   'PRNV094': 34,
#   'PRNV095': 60,
#   'PRNV096': 69,
#   'PRNV097': 58,
#   'PRNV098': 31,
#   'PRNV100': 30,
#   'PRNV102': 43,
#   'PRNV103': 33,
#   'PRNV104': 33,
#   'PRNV105': 38,
#   'PRNV106': 43,
#   'PRNV107': 29,
#   'PRNV109': 32,
#   'PRNV114': 44,
#   'PRNV115': 58,
#   'PRNV116': 41,
#   'PRNV117': 46,
#   'PRNV118': 38,
#   'PRNV121': 29,
#   'PRNV122': 41,
#   'PRNV125': 33,
#   'PRNV126': 30,
#   'PRNV139': 35,
#   'PRNV141': 29,
#   'PRNV142': 37,
#   'PRNV143': 42,
#   'PRNV144': 33,
#   'PRNV145': 29,
#   'PRNV146': 35,
#   'PRNV147': 36,
#   'PRNV148': 30,
#   'PRNV149': 50,
#   'PRNV150': 32,
#   'PRNV152': 53,
#   'PRNV153': 30,
#   'PRNV172': 50,
#   'PRNV174': 42,
#   'PRNV177': 56,
#   'PRSH016': 36},
#  'Validation': {'NACHM054': 23,
#   'PRNV028': 26,
#   'PRNV030': 28,
#   'PRNV032': 6,
#   'PRNV035': 27,
#   'PRNV038': 27,
#   'PRNV041': 28,
#   'PRNV050': 26,
#   'PRNV051': 26,
#   'PRNV062': 24,
#   'PRNV066': 27,
#   'PRNV067': 26,
#   'PRNV074': 25,
#   'PRNV075': 27,
#   'PRNV077': 26,
#   'PRNV079': 25,
#   'PRNV080': 24,
#   'PRNV084': 27,
#   'PRNV099': 25,
#   'PRNV124': 25,
#   'PRNV140': 25,
#   'PRNV157': 24,
#   'PRNV161': 27,
#   'PRNV175': 24,
#   'PRSH014': 26,
#   'PRSH022': 24,
#   'PRSH023': 27}}

# %%
def findProportion_all(Size=None):
  data = {}
  for i in range(8):
    category = DOMAIN_DICT[i]
    df = DF.loc[DF['Category'] == category]
    
    if Size != None:
      df.sample(frac=1,random_state=69).reset_index(drop=True)
      df = df[:Size]

    countValues = df['Serials'].value_counts()
    data[category] = findProportion(countValues,size=Size)
  return data

# %%
FIX_SIZE = 2500
proportionDict = findProportion_all(FIX_SIZE)
pd.DataFrame.from_dict(proportionDict)
# Out:
#                                                   Imaginative  \
# Train       {'PRNV008': 67, 'PRNV006': 61, 'PRNV025': 58, ...
# Validation  {'PRNV066': 27, 'PRNV035': 27, 'PRNV067': 26, ...
# Test        {'PRNV073': 23, 'NACHM054': 23, 'PRNV015': 22,...
#
#                                        Natural & Pure Science  \
# Train       {'NACMD070': 200, 'NACMD069': 195, 'NACMD080':...
# Validation  {'MG004': 66, 'ACNS001': 54, 'NACMD073': 53, '...
# Test        {'NACMD056': 33, 'MG027': 28, 'MG030': 28, 'MG...
#
#                                               Applied Science  \
# Train       {'ACET011': 341, 'ACET007': 300, 'ACET005': 26...
# Validation                   {'ACET012': 209, 'ACET009': 128}
# Test        {'ACET006': 131, 'ACET002': 108, 'ACET013': 88...
#
#                                               Social Science   \
# Train       {'ACSS093': 192, 'ACSS043': 132, 'ACSS057': 67...
# Validation  {'ACSS083': 28, 'ACSS080': 27, 'ACSS052': 27, ...
# Test        {'ACSS047': 22, 'ACSS042': 21, 'ACSS032': 21, ...
#
#                                                       History  \
# Train          {'ACSS153': 835, 'ACSS078': 698, 'IRP055': 42}
# Validation                    {'ACSS125': 239, 'ACSS119': 98}
# Test        {'IRP026': 71, 'IRP006': 51, 'IRP004': 29, 'IR...
#
#                                            Commerce & Finance  \
# Train       {'COM001': 530, 'IRP362': 246, 'INST008': 161,...
# Validation  {'IRP156': 23, 'IRP384': 22, 'IRP358': 21, 'IR...
# Test        {'IRP350': 11, 'IRP260': 11, 'IRP381': 10, 'IR...
#
#                                                          Arts  \
# Train       {'ACHM010': 223, 'ACHM032': 220, 'ACHM034': 18...
# Validation    {'ACHM035': 147, 'ACHM008': 145, 'ACHM017': 45}
# Test        {'ACHM031': 100, 'ACHM018': 81, 'ACHM016': 78,...
#
#                                              Belief & Thought
# Train       {'NACHM067': 599, 'NACHM068': 216, 'NACHM069':...
# Validation  {'NACHM103': 148, 'NACHM099': 146, 'NACHM100':...
# Test        {'NACHM101': 122, 'NACHM102': 116, 'MG029': 94...

# %%
proportionDict
# Out:
# {'Applied Science': {'Test': {'ACET001': 10,
#    'ACET002': 108,
#    'ACET006': 131,
#    'ACET013': 88},
#   'Train': {'ACET004': 241,
#    'ACET005': 266,
#    'ACET007': 300,
#    'ACET010': 186,
#    'ACET011': 341,
#    'ACET014': 241},
#   'Validation': {'ACET009': 128, 'ACET012': 209}},
#  'Arts': {'Test': {'ACHM016': 78,
#    'ACHM018': 81,
#    'ACHM019': 12,
#    'ACHM029': 66,
#    'ACHM031': 100},
#   'Train': {'ACHM004': 184,
#    'ACHM005': 173,
#    'ACHM007': 182,
#    'ACHM009': 73,
#    'ACHM010': 223,
#    'ACHM011': 167,
#    'ACHM025': 166,
#    'ACHM032': 220,
#    'ACHM034': 187},
#   'Validation': {'ACHM008': 145, 'ACHM017': 45, 'ACHM035': 147}},
#  'Belief & Thought': {'Test': {'MG029': 94,
#    'NACHM101': 122,
#    'NACHM102': 116,
#    'NACHM104': 5},
#   'Train': {'ACHM030': 139,
#    'ACHM041': 204,
#    'NACHM067': 599,
#    'NACHM068': 216,
#    'NACHM069': 209,
#    'NACHM098': 208},
#   'Validation': {'NACHM099': 146, 'NACHM100': 43, 'NACHM103': 148}},
#  'Commerce & Finance': {'Test': {'IRP012': 5,
#    'IRP102': 7,
#    'IRP103': 7,
#    'IRP120': 9,
#    'IRP153': 5,
#    'IRP170': 10,
#    'IRP172': 7,
#    'IRP186': 6,
#    'IRP203': 9,
#    'IRP204': 6,
#    'IRP205': 7,
#    'IRP207': 5,
#    'IRP214': 5,
#    'IRP216': 5,
#    'IRP225': 6,
#    'IRP260': 11,
#    'IRP272': 7,
#    'IRP331': 5,
#    'IRP333': 5,
#    'IRP347': 8,
#    'IRP348': 6,
#    'IRP350': 11,
#    'IRP357': 4,
#    'IRP359': 9,
#    'IRP360': 8,
#    'IRP361': 6,
#    'IRP381': 10,
#    'IRP385': 6,
#    'IRP393': 6,
#    'IRP396': 5,
#    'IRP398': 9,
#    'IRP399': 6,
#    'IRP408': 5,
#    'IRP409': 5,
#    'IRP412': 8,
#    'IRP413': 6,
#    'IRP421': 5,
#    'IRP424': 7,
#    'IRP425': 6,
#    'IRP431': 8,
#    'IRP438': 5,
#    'IRP439': 5,
#    'IRP454': 6,
#    'IRP459': 9,
#    'LW036': 6,
#    'LW042': 8,
#    'LW055': 7,
#    'LW069': 8,
#    'LW083': 5,
#    'LW091': 7},
#   'Train': {'COM001': 530,
#    'INST004': 33,
#    'INST008': 161,
#    'IRP016': 26,
#    'IRP157': 29,
#    'IRP195': 10,
#    'IRP261': 25,
#    'IRP326': 30,
#    'IRP355': 25,
#    'IRP362': 246,
#    'IRP378': 27,
#    'LW003': 37,
#    'LW004': 77,
#    'LW045': 30,
#    'LW065': 33,
#    'LW070': 50,
#    'LW071': 61,
#    'LW151': 56,
#    'LW152': 52,
#    'LW153': 37},
#   'Validation': {'IRP037': 21,
#    'IRP152': 21,
#    'IRP156': 23,
#    'IRP171': 14,
#    'IRP184': 12,
#    'IRP206': 15,
#    'IRP237': 15,
#    'IRP344': 16,
#    'IRP354': 14,
#    'IRP358': 21,
#    'IRP367': 13,
#    'IRP384': 22,
#    'IRP401': 14,
#    'IRP415': 12,
#    'IRP423': 12,
#    'IRP445': 14,
#    'LW002': 12,
#    'LW046': 21,
#    'LW057': 3,
#    'LW062': 16,
#    'LW068': 14,
#    'LW072': 12}},
#  'History': {'Test': {'IRP004': 29, 'IRP006': 51, 'IRP026': 71, 'IRP042': 28},
#   'Train': {'ACSS078': 698, 'ACSS153': 835, 'IRP055': 42},
#   'Validation': {'ACSS119': 98, 'ACSS125': 239}},
#  'Imaginative': {'Test': {'NACHM': 17,
#    'NACHM054': 23,
#    'PRNV011': 21,
#    'PRNV015': 22,
#    'PRNV018': 21,
#    'PRNV019': 20,
#    'PRNV033': 18,
#    'PRNV04': 16,
#    'PRNV05': 20,
#    'PRNV060': 19,
#    'PRNV063': 18,
#    'PRNV064': 17,
#    'PRNV065': 19,
#    'PRNV068': 20,
#    'PRNV069': 19,
#    'PRNV073': 23,
#    'PRNV082': 22,
#    'PRNV089': 2},
#   'Train': {'POET023': 50,
#    'PRNV': 51,
#    'PRNV001': 35,
#    'PRNV002': 42,
#    'PRNV003': 43,
#    'PRNV006': 61,
#    'PRNV007': 38,
#    'PRNV008': 67,
#    'PRNV01': 29,
#    'PRNV010': 44,
#    'PRNV012': 42,
#    'PRNV013': 53,
#    'PRNV014': 35,
#    'PRNV016': 47,
#    'PRNV017': 29,
#    'PRNV020': 31,
#    'PRNV022': 29,
#    'PRNV023': 41,
#    'PRNV024': 29,
#    'PRNV025': 58,
#    'PRNV026': 31,
#    'PRNV029': 29,
#    'PRNV030': 28,
#    'PRNV036': 33,
#    'PRNV037': 29,
#    'PRNV038': 27,
#    'PRNV039': 41,
#    'PRNV040': 32,
#    'PRNV041': 28,
#    'PRNV044': 34,
#    'PRNV045': 31,
#    'PRNV047': 31,
#    'PRNV049': 29,
#    'PRNV052': 29,
#    'PRNV070': 32,
#    'PRNV071': 42,
#    'PRNV072': 29,
#    'PRNV075': 27,
#    'PRNV081': 30,
#    'PRNV083': 28,
#    'PRNV084': 2,
#    'PRNV085': 37,
#    'PRNV087': 31,
#    'PRNV088': 31},
#   'Validation': {'PRNV028': 26,
#    'PRNV032': 23,
#    'PRNV034': 9,
#    'PRNV035': 27,
#    'PRNV046': 23,
#    'PRNV050': 26,
#    'PRNV051': 26,
#    'PRNV062': 24,
#    'PRNV066': 27,
#    'PRNV067': 26,
#    'PRNV074': 25,
#    'PRNV077': 26,
#    'PRNV079': 25,
#    'PRNV080': 24}},
#  'Natural & Pure Science': {'Test': {'IRP133': 19,
#    'MG006': 18,
#    'MG008': 25,
#    'MG013': 23,
#    'MG016': 27,
#    'MG022': 24,
#    'MG023': 15,
#    'MG027': 28,
#    'MG030': 28,
#    'NACMD056': 33,
#    'NACMD058': 13,
#    'NACMD059': 17,
#    'NACMD060': 9,
#    'NACMD071': 12,
#    'NACMD076': 20,
#    'NACMD079': 13,
#    'NACMD083': 13},
#   'Train': {'NACMD050': 92,
#    'NACMD052': 129,
#    'NACMD053': 129,
#    'NACMD057': 7,
#    'NACMD063': 97,
#    'NACMD064': 97,
#    'NACMD066': 126,
#    'NACMD067': 151,
#    'NACMD069': 195,
#    'NACMD070': 200,
#    'NACMD072': 96,
#    'NACMD074': 87,
#    'NACMD080': 169},
#   'Validation': {'ACNS001': 54,
#    'MG004': 66,
#    'MG007': 41,
#    'MG055': 3,
#    'MG056': 42,
#    'NACMD055': 35,
#    'NACMD073': 53,
#    'NACMD075': 43}},
#  'Social Science ': {'Test': {'ACHM063': 20,
#    'ACSS009': 17,
#    'ACSS010': 16,
#    'ACSS012': 17,
#    'ACSS032': 21,
#    'ACSS035': 18,
#    'ACSS038': 20,
#    'ACSS039': 17,
#    'ACSS040': 21,
#    'ACSS042': 21,
#    'ACSS046': 20,
#    'ACSS047': 22,
#    'ACSS048': 17,
#    'ACSS051': 19,
#    'ACSS060': 17,
#    'ACSS073': 17,
#    'ACSS076': 17,
#    'ACSS082': 20},
#   'Train': {'ACHM050': 61,
#    'ACPL001': 45,
#    'ACPL002': 64,
#    'ACPL003': 44,
#    'ACPL004': 35,
#    'ACPL005': 64,
#    'ACSS011': 29,
#    'ACSS015': 33,
#    'ACSS016': 33,
#    'ACSS017': 40,
#    'ACSS019': 40,
#    'ACSS026': 28,
#    'ACSS027': 46,
#    'ACSS028': 28,
#    'ACSS031': 29,
#    'ACSS036': 45,
#    'ACSS043': 132,
#    'ACSS056': 39,
#    'ACSS057': 67,
#    'ACSS059': 39,
#    'ACSS061': 19,
#    'ACSS067': 32,
#    'ACSS071': 38,
#    'ACSS075': 30,
#    'ACSS077': 29,
#    'ACSS079': 37,
#    'ACSS081': 36,
#    'ACSS084': 29,
#    'ACSS085': 35,
#    'ACSS086': 42,
#    'ACSS087': 32,
#    'ACSS088': 30,
#    'ACSS092': 53,
#    'ACSS093': 192},
#   'Validation': {'ACSS013': 25,
#    'ACSS041': 25,
#    'ACSS044': 25,
#    'ACSS045': 24,
#    'ACSS050': 24,
#    'ACSS052': 27,
#    'ACSS054': 26,
#    'ACSS055': 11,
#    'ACSS069': 25,
#    'ACSS072': 22,
#    'ACSS080': 27,
#    'ACSS083': 28,
#    'ACSS089': 23,
#    'ACSS090': 25}}}

# %%
def getProportionPair(proportionDict):
  data = {}

  trainLST =  []
  valLST = []
  testLST = []
  
  for i in range(8):
    domain = DOMAIN_DICT[i]
    splitPorpDict = proportionDict[domain]
    
    trainLST += [pair for pair in list(splitPorpDict['Train'].items())]
    valLST += [pair for pair in list(splitPorpDict['Validation'].items())]
    testLST += [pair for pair in list(splitPorpDict['Test'].items())]

  data['Train'] = trainLST
  data['Validation'] = valLST
  data['Test'] = testLST

  return data

# %%
portpotionPair = getProportionPair(proportionDict)
portpotionPair
# Out:
# {'Test': [('PRNV073', 23),
#   ('NACHM054', 23),
#   ('PRNV015', 22),
#   ('PRNV082', 22),
#   ('PRNV018', 21),
#   ('PRNV011', 21),
#   ('PRNV068', 20),
#   ('PRNV019', 20),
#   ('PRNV05', 20),
#   ('PRNV065', 19),
#   ('PRNV069', 19),
#   ('PRNV060', 19),
#   ('PRNV033', 18),
#   ('PRNV063', 18),
#   ('PRNV064', 17),
#   ('NACHM', 17),
#   ('PRNV04', 16),
#   ('PRNV089', 2),
#   ('NACMD056', 33),
#   ('MG027', 28),
#   ('MG030', 28),
#   ('MG016', 27),
#   ('MG008', 25),
#   ('MG022', 24),
#   ('MG013', 23),
#   ('NACMD076', 20),
#   ('IRP133', 19),
#   ('MG006', 18),
#   ('NACMD059', 17),
#   ('MG023', 15),
#   ('NACMD058', 13),
#   ('NACMD079', 13),
#   ('NACMD083', 13),
#   ('NACMD071', 12),
#   ('NACMD060', 9),
#   ('ACET006', 131),
#   ('ACET002', 108),
#   ('ACET013', 88),
#   ('ACET001', 10),
#   ('ACSS047', 22),
#   ('ACSS042', 21),
#   ('ACSS032', 21),
#   ('ACSS040', 21),
#   ('ACSS046', 20),
#   ('ACSS038', 20),
#   ('ACHM063', 20),
#   ('ACSS082', 20),
#   ('ACSS051', 19),
#   ('ACSS035', 18),
#   ('ACSS076', 17),
#   ('ACSS073', 17),
#   ('ACSS060', 17),
#   ('ACSS012', 17),
#   ('ACSS009', 17),
#   ('ACSS048', 17),
#   ('ACSS039', 17),
#   ('ACSS010', 16),
#   ('IRP026', 71),
#   ('IRP006', 51),
#   ('IRP004', 29),
#   ('IRP042', 28),
#   ('IRP350', 11),
#   ('IRP260', 11),
#   ('IRP381', 10),
#   ('IRP170', 10),
#   ('IRP398', 9),
#   ('IRP459', 9),
#   ('IRP359', 9),
#   ('IRP120', 9),
#   ('IRP203', 9),
#   ('IRP412', 8),
#   ('IRP360', 8),
#   ('LW042', 8),
#   ('IRP431', 8),
#   ('LW069', 8),
#   ('IRP347', 8),
#   ('LW091', 7),
#   ('IRP172', 7),
#   ('LW055', 7),
#   ('IRP205', 7),
#   ('IRP103', 7),
#   ('IRP102', 7),
#   ('IRP272', 7),
#   ('IRP424', 7),
#   ('LW036', 6),
#   ('IRP361', 6),
#   ('IRP385', 6),
#   ('IRP186', 6),
#   ('IRP399', 6),
#   ('IRP413', 6),
#   ('IRP425', 6),
#   ('IRP225', 6),
#   ('IRP393', 6),
#   ('IRP204', 6),
#   ('IRP348', 6),
#   ('IRP454', 6),
#   ('IRP396', 5),
#   ('IRP408', 5),
#   ('IRP438', 5),
#   ('IRP409', 5),
#   ('IRP012', 5),
#   ('IRP153', 5),
#   ('IRP439', 5),
#   ('IRP421', 5),
#   ('IRP216', 5),
#   ('LW083', 5),
#   ('IRP331', 5),
#   ('IRP207', 5),
#   ('IRP214', 5),
#   ('IRP333', 5),
#   ('IRP357', 4),
#   ('ACHM031', 100),
#   ('ACHM018', 81),
#   ('ACHM016', 78),
#   ('ACHM029', 66),
#   ('ACHM019', 12),
#   ('NACHM101', 122),
#   ('NACHM102', 116),
#   ('MG029', 94),
#   ('NACHM104', 5)],
#  'Train': [('PRNV008', 67),
#   ('PRNV006', 61),
#   ('PRNV025', 58),
#   ('PRNV013', 53),
#   ('PRNV', 51),
#   ('POET023', 50),
#   ('PRNV016', 47),
#   ('PRNV010', 44),
#   ('PRNV003', 43),
#   ('PRNV071', 42),
#   ('PRNV002', 42),
#   ('PRNV012', 42),
#   ('PRNV023', 41),
#   ('PRNV039', 41),
#   ('PRNV007', 38),
#   ('PRNV085', 37),
#   ('PRNV014', 35),
#   ('PRNV001', 35),
#   ('PRNV044', 34),
#   ('PRNV036', 33),
#   ('PRNV040', 32),
#   ('PRNV070', 32),
#   ('PRNV045', 31),
#   ('PRNV020', 31),
#   ('PRNV047', 31),
#   ('PRNV087', 31),
#   ('PRNV088', 31),
#   ('PRNV026', 31),
#   ('PRNV081', 30),
#   ('PRNV022', 29),
#   ('PRNV017', 29),
#   ('PRNV024', 29),
#   ('PRNV037', 29),
#   ('PRNV049', 29),
#   ('PRNV01', 29),
#   ('PRNV052', 29),
#   ('PRNV072', 29),
#   ('PRNV029', 29),
#   ('PRNV041', 28),
#   ('PRNV083', 28),
#   ('PRNV030', 28),
#   ('PRNV075', 27),
#   ('PRNV038', 27),
#   ('PRNV084', 2),
#   ('NACMD070', 200),
#   ('NACMD069', 195),
#   ('NACMD080', 169),
#   ('NACMD067', 151),
#   ('NACMD052', 129),
#   ('NACMD053', 129),
#   ('NACMD066', 126),
#   ('NACMD063', 97),
#   ('NACMD064', 97),
#   ('NACMD072', 96),
#   ('NACMD050', 92),
#   ('NACMD074', 87),
#   ('NACMD057', 7),
#   ('ACET011', 341),
#   ('ACET007', 300),
#   ('ACET005', 266),
#   ('ACET004', 241),
#   ('ACET014', 241),
#   ('ACET010', 186),
#   ('ACSS093', 192),
#   ('ACSS043', 132),
#   ('ACSS057', 67),
#   ('ACPL005', 64),
#   ('ACPL002', 64),
#   ('ACHM050', 61),
#   ('ACSS092', 53),
#   ('ACSS027', 46),
#   ('ACSS036', 45),
#   ('ACPL001', 45),
#   ('ACPL003', 44),
#   ('ACSS086', 42),
#   ('ACSS019', 40),
#   ('ACSS017', 40),
#   ('ACSS056', 39),
#   ('ACSS059', 39),
#   ('ACSS071', 38),
#   ('ACSS079', 37),
#   ('ACSS081', 36),
#   ('ACPL004', 35),
#   ('ACSS085', 35),
#   ('ACSS016', 33),
#   ('ACSS015', 33),
#   ('ACSS087', 32),
#   ('ACSS067', 32),
#   ('ACSS075', 30),
#   ('ACSS088', 30),
#   ('ACSS084', 29),
#   ('ACSS077', 29),
#   ('ACSS011', 29),
#   ('ACSS031', 29),
#   ('ACSS026', 28),
#   ('ACSS028', 28),
#   ('ACSS061', 19),
#   ('ACSS153', 835),
#   ('ACSS078', 698),
#   ('IRP055', 42),
#   ('COM001', 530),
#   ('IRP362', 246),
#   ('INST008', 161),
#   ('LW004', 77),
#   ('LW071', 61),
#   ('LW151', 56),
#   ('LW152', 52),
#   ('LW070', 50),
#   ('LW003', 37),
#   ('LW153', 37),
#   ('LW065', 33),
#   ('INST004', 33),
#   ('LW045', 30),
#   ('IRP326', 30),
#   ('IRP157', 29),
#   ('IRP378', 27),
#   ('IRP016', 26),
#   ('IRP261', 25),
#   ('IRP355', 25),
#   ('IRP195', 10),
#   ('ACHM010', 223),
#   ('ACHM032', 220),
#   ('ACHM034', 187),
#   ('ACHM004', 184),
#   ('ACHM007', 182),
#   ('ACHM005', 173),
#   ('ACHM011', 167),
#   ('ACHM025', 166),
#   ('ACHM009', 73),
#   ('NACHM067', 599),
#   ('NACHM068', 216),
#   ('NACHM069', 209),
#   ('NACHM098', 208),
#   ('ACHM041', 204),
#   ('ACHM030', 139)],
#  'Validation': [('PRNV066', 27),
#   ('PRNV035', 27),
#   ('PRNV067', 26),
#   ('PRNV077', 26),
#   ('PRNV028', 26),
#   ('PRNV051', 26),
#   ('PRNV050', 26),
#   ('PRNV079', 25),
#   ('PRNV074', 25),
#   ('PRNV062', 24),
#   ('PRNV080', 24),
#   ('PRNV046', 23),
#   ('PRNV032', 23),
#   ('PRNV034', 9),
#   ('MG004', 66),
#   ('ACNS001', 54),
#   ('NACMD073', 53),
#   ('NACMD075', 43),
#   ('MG056', 42),
#   ('MG007', 41),
#   ('NACMD055', 35),
#   ('MG055', 3),
#   ('ACET012', 209),
#   ('ACET009', 128),
#   ('ACSS083', 28),
#   ('ACSS080', 27),
#   ('ACSS052', 27),
#   ('ACSS054', 26),
#   ('ACSS069', 25),
#   ('ACSS013', 25),
#   ('ACSS090', 25),
#   ('ACSS044', 25),
#   ('ACSS041', 25),
#   ('ACSS050', 24),
#   ('ACSS045', 24),
#   ('ACSS089', 23),
#   ('ACSS072', 22),
#   ('ACSS055', 11),
#   ('ACSS125', 239),
#   ('ACSS119', 98),
#   ('IRP156', 23),
#   ('IRP384', 22),
#   ('IRP358', 21),
#   ('IRP152', 21),
#   ('LW046', 21),
#   ('IRP037', 21),
#   ('IRP344', 16),
#   ('LW062', 16),
#   ('IRP237', 15),
#   ('IRP206', 15),
#   ('IRP445', 14),
#   ('IRP171', 14),
#   ('IRP401', 14),
#   ('IRP354', 14),
#   ('LW068', 14),
#   ('IRP367', 13),
#   ('IRP184', 12),
#   ('LW002', 12),
#   ('LW072', 12),
#   ('IRP423', 12),
#   ('IRP415', 12),
#   ('LW057', 3),
#   ('ACHM035', 147),
#   ('ACHM008', 145),
#   ('ACHM017', 45),
#   ('NACHM103', 148),
#   ('NACHM099', 146),
#   ('NACHM100', 43)]}

# %%
def splitData(portpotionPair):
  splitTags = ['Train','Validation','Test']
  main_df = pd.DataFrame(columns=DF.columns)
  for tag in splitTags:
    main_df = main_df.iloc[0:0]
    for pair in portpotionPair[tag]:
      serial = pair[0]
      amount = pair[1]

      add_df = DF.loc[DF['Serials'] == serial]

      add_df.drop(add_df.index[amount:], inplace=True)

      main_df = pd.concat([main_df,add_df]).reset_index(drop=True)
    main_df.to_csv(f'TNC_{tag}Set_{FIX_SIZE}.csv', index=False)
    print(f'Export {tag} complete!!!')

# %%
splitData(portpotionPair)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Export Train complete!!!
# Export Validation complete!!!
# Export Test complete!!!

# %%
trainDF = pd.read_csv(f'TNC_TrainSet_{FIX_SIZE}.csv')
trainDF
# Out:
#        Serials          Category  \
# 0      PRNV008       Imaginative
# 1      PRNV008       Imaginative
# 2      PRNV008       Imaginative
# 3      PRNV008       Imaginative
# 4      PRNV008       Imaginative
# ...        ...               ...
# 12595  ACHM030  Belief & Thought
# 12596  ACHM030  Belief & Thought
# 12597  ACHM030  Belief & Thought
# 12598  ACHM030  Belief & Thought
# 12599  ACHM030  Belief & Thought
#
#                                                    Texts
# 0        นิรนารู้สึกไม่สบายใจกับทุกถ้อยคําที่ดูเหมือน...
# 1        เขาตอกย้ําคําว่าอร่อยของตัวเองด้วยรอยยิ้มภูม...
# 2      ไม่ใช่อย่างนั้นนะครับ คือผม." เขาทําท่าลําบากใ...
# 3        เราแวะไปกินหลังมื้อกลางวันก็ได้ ผมรู้จักร้าน...
# 4        หัวใจฉันสั่นไหว รับรู้ว่าตัวเองยืนอยู่ ณ ที่...
# ...                                                  ...
# 12595    แต่คนไทลื้อก็โยกย้ายถิ่นฐานบ้าง อพยพบ้าง ถูก...
# 12596    ผู้วิจัยเคยไปหมู่บ้านไทลื้อ 2 ครั้ง คือเมื่อ...
# 12597    ทางด้านความเชื่อและศาสนา คนลาวก็เช่นเดียวกัน...
# 12598    ไทใหญ่ในประเทศต่าง ๆ จะมีชื่อเรียกต่างกันไป ...
# 12599    ศรีศักร วัลลิโภดมประเมินความเก่าแก่และความแข...
#
# [12600 rows x 3 columns]

# %%
valDF = pd.read_csv(f'TNC_ValidationSet_{FIX_SIZE}.csv')
valDF
# Out:
#        Serials          Category  \
# 0      PRNV066       Imaginative
# 1      PRNV066       Imaginative
# 2      PRNV066       Imaginative
# 3      PRNV066       Imaginative
# 4      PRNV066       Imaginative
# ...        ...               ...
# 2691  NACHM100  Belief & Thought
# 2692  NACHM100  Belief & Thought
# 2693  NACHM100  Belief & Thought
# 2694  NACHM100  Belief & Thought
# 2695  NACHM100  Belief & Thought
#
#                                                   Texts
# 0       เอาไปคืนเองสิ  " นี่ แต่ฉันไม่รู้จักเจ้าของม...
# 1       นักเรียนหญิงผมสั้นที่ได้ตําแหน่งเป็นราชินีไพ...
# 2       เสียงของไอ้เจ้ามินตัวดีดังมาจากหน้าประตูห้อง...
# 3       งั้นแกก็ลองไปดูดวงสิเห็นเอาแต่โทษดวงชะตาอยู่...
# 4       ฉันครางตอบอย่างเหนื่อยหน่ายไม่ได้เดามั่วนะ ก...
# ...                                                 ...
# 2691    โลกนี้ไม่มีคนปราศจากอคติ แต่ก็มีการฝึกฝนอบรม...
# 2692    ปริมาณสัตว์ที่รอดเพราะการอธิษฐานร่วมกัน จะก่...
# 2693    ๒ การตรวจสอบแบบที่มีเจตนาหาจุดอ่อนของคู่แข่ง...
# 2694    สรุปคือแม้ตบยุง บี้มด ฆ่าแมลง ถึงเห็นเป็นสัต...
# 2695    อย่างไรก็ตาม เมื่อผู้มีหน้าที่ตรวจสอบในแนวทา...
#
# [2696 rows x 3 columns]

# %%
testDF = pd.read_csv(f'TNC_TestSet_{FIX_SIZE}.csv')
testDF
# Out:
#        Serials          Category  \
# 0      PRNV073       Imaginative
# 1      PRNV073       Imaginative
# 2      PRNV073       Imaginative
# 3      PRNV073       Imaginative
# 4      PRNV073       Imaginative
# ...        ...               ...
# 2533  NACHM104  Belief & Thought
# 2534  NACHM104  Belief & Thought
# 2535  NACHM104  Belief & Thought
# 2536  NACHM104  Belief & Thought
# 2537  NACHM104  Belief & Thought
#
#                                                   Texts
# 0       ต้าหันไปถามเรียวที่ยิ้มบางๆ ให้ หน้าเขาขึ้นส...
# 1       ยัยแตมป์ที่เพิ่งวางไมโครโฟนลงจากการร้องเพลงม...
# 2       ฉันเก็บมือถือเข้ากระเป๋าและเดินกลับเข้าไปข้า...
# 3       หึ ฉันน่าจะเป็นคนขอบคุณเธอมากกว่า ^_^" ตลกน่...
# 4       กอลลัมไงล่ะ ไม่ใช่ ล้อเล่นน่า เขาอยู่ในชุด เ...
# ...                                                 ...
# 2533    ศีลจะมีส่วนช่วยปรุงแต่งหน้าตาให้ดูดีจริงๆต่อ...
# 2534    ต่อไปนี้เมื่อพูดถึงความสวยหรือความงาม ขอให้เ...
# 2535     ถาม บางทีไม่แน่ใจว่าทําอะไรไปด้วยเจตนาแบบไห...
# 2536     ถ้าหากประกอบพร้อมทั้งการให้ทรัพย์เป็นทานด้ว...
# 2537    น่าเสียดายในปัจจุบันคนสวยหล่อทั้งหลายเอาเครื...
#
# [2538 rows x 3 columns]
